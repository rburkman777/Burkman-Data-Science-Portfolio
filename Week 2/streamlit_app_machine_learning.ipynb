# %%
import streamlit as st

st.title("Machine Learning Streamlit App")
# Out:
# 2026-04-04 16:42:57.183 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-04 16:42:57.228
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /opt/miniconda3/lib/python3.13/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-04-04 16:42:57.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-04 16:42:57.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.write("Welcome! Let's start by uploading your dataset! You can upload it as a CSV here:")

uploaded_file = st.file_uploader("Upload a CSV")

if uploaded_file:
    import pandas as pd
    df = pd.read_csv(uploaded_file)
    st.write(df)
